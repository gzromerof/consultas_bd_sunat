# %% [markdown]
# <a href="https://colab.research.google.com/github/gzromerof/consultas_bd_sunat/blob/main/multiorigenes2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#OPCION DE CARGA N° 1
#Matriz_MC es la matriz que contiene a las empresas ya clasificadas por Tamaño
import pandas as pd
##df= pd.read_excel('NOMRE_EXCEL.xlsx', sheet_name='NOMBRE_HOJA_EXCEL')
df= pd.read_excel('Base_Ene_MC2.xlsx', sheet_name='Base_Ene_MC')
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#OPCION DE CARGA N° 2
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#OPCION DE CARGA N° 2
#Matriz_MC es la matriz que contiene a las empresas ya clasificadas por Tamaño
import pandas as pd
##df= pd.read_excel('/content/drive/MyDrive/NOMBRE_CARPETA_DRIVE/NOMRE_EXCEL.xlsx', sheet_name='NOMBRE_HOJA_EXCEL')
df= pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Adex/Base_Ene_MC.xlsx', sheet_name='Base_Ene_MC')
df
# Out:
#           AA  MM NUM_DOCUMENTO                        DECLARANTE  \
# 0       2022   1   20100003512  INDUSTRIAS ELECTRO QUIMICAS S.A.
# 1       2022   1   20100003512  INDUSTRIAS ELECTRO QUIMICAS S.A.
# 2       2022   1   20100003512  INDUSTRIAS ELECTRO QUIMICAS S.A.
# 3       2022   1   20100003512  INDUSTRIAS ELECTRO QUIMICAS S.A.
# 4       2022   1   20100003512  INDUSTRIAS ELECTRO QUIMICAS S.A.
# ...      ...  ..           ...                               ...
# 241028  2023   6   Ley 29733 P                               NaN
# 241029  2023   6   Ley 29733 P                               NaN
# 241030  2023   6   Ley 29733 P                               NaN
# 241031  2023   6   Ley 29733 P                               NaN
# 241032  2023   6   Ley 29733 P                               NaN
#
#        NOMB_CONTINENTE_ES COD_PAIS NOMB_PAIS_ES          NOMB_VIA_ES  \
# 0                  AFRICA       MA    MARRUECOS             MARITIMO
# 1         AMERICA DEL SUR       BR       BRASIL             MARITIMO
# 2         AMERICA DEL SUR       CO     COLOMBIA             MARITIMO
# 3         AMERICA DEL SUR       CO     COLOMBIA  TERRESTRE/CARRETERA
# 4                  EUROPA       GB  REINO UNIDO             MARITIMO
# ...                   ...      ...          ...                  ...
# 241028             EUROPA       FR      FRANCIA                AEREA
# 241029             EUROPA       PL      POLONIA                AEREA
# 241030            OCEANIA       AU    AUSTRALIA                AEREA
# 241031            OCEANIA       AU    AUSTRALIA                AEREA
# 241032            OCEANIA       AU    AUSTRALIA                AEREA
#
#                         SECTOR_ES     PARTIDA  \
# 0                         QUIMICO  2817001000
# 1       SIDERURGICO Y METALURGICO  7905000091
# 2                         QUIMICO  2817001000
# 3                         QUIMICO  2817001000
# 4             MINERIA TRADICIONAL  7901110000
# ...                           ...         ...
# 241028        MINERIA NO METALICA  6802210000
# 241029                     VARIOS  4202991000
# 241030          PRENDAS DE VESTIR  6101300000
# 241031          PRENDAS DE VESTIR  6110191090
# 241032          PRENDAS DE VESTIR  6110301000
#
#                                       DESC_ARANCELARIA_ES    DPTO        FOB  \
# 0                   OXIDO DE CINC (BLANCO O FLOR DE CINC)  CALLAO   76842.48
# 1       DISCOS, HEXAGONOS,DE CINC CUYA MAYOR DIMENSION...  CALLAO  625739.50
# 2                   OXIDO DE CINC (BLANCO O FLOR DE CINC)  CALLAO  556315.92
# 3                   OXIDO DE CINC (BLANCO O FLOR DE CINC)  CALLAO   86629.08
# 4       CINC SIN ALEAR, CON UN CONTENIDO DE CINC SUPER...  CALLAO  196957.91
# ...                                                   ...     ...        ...
# 241028  MARMOL,TRAVERTINOS Y ALABASTRO,SIMPLEMENTE TAL...    LIMA     120.00
# 241029                    DEMAS SACOS DE VIAJE Y MOCHILAS    LIMA     158.70
# 241030  ABRIGOS,CHAQ.,CAPAS Y ART. SIMIL.DE PTO, PARA ...    LIMA    1670.40
# 241031  DEMÁS SUÉTERES (JERSEYS), DE PUNTO, DE LAS DEM...  CALLAO     358.80
# 241032  SUETERES, PULLOVERS, CARDIGANS, CHALECOS Y ART...  CALLAO    1785.24
#
#                                          RUC_EMPRESA                 RUBRO  \
# 0       20100003512 INDUSTRIAS ELECTRO QUIMICAS S.A.  TOTAL NO TRADICIONAL
# 1       20100003512 INDUSTRIAS ELECTRO QUIMICAS S.A.  TOTAL NO TRADICIONAL
# 2       20100003512 INDUSTRIAS ELECTRO QUIMICAS S.A.  TOTAL NO TRADICIONAL
# 3       20100003512 INDUSTRIAS ELECTRO QUIMICAS S.A.  TOTAL NO TRADICIONAL
# 4       20100003512 INDUSTRIAS ELECTRO QUIMICAS S.A.     TOTAL TRADICIONAL
# ...                                              ...                   ...
# 241028                              Ley 29733 P NULL  TOTAL NO TRADICIONAL
# 241029                              Ley 29733 P NULL  TOTAL NO TRADICIONAL
# 241030                              Ley 29733 P NULL  TOTAL NO TRADICIONAL
# 241031                              Ley 29733 P NULL  TOTAL NO TRADICIONAL
# 241032                              Ley 29733 P NULL  TOTAL NO TRADICIONAL
#
#                                          Partida_Producto         REGION  \
# 0        2817001000 OXIDO DE CINC (BLANCO O FLOR DE CINC)  LIMA Y CALLAO
# 1       7905000091 DISCOS, HEXAGONOS,DE CINC CUYA MAYO...  LIMA Y CALLAO
# 2        2817001000 OXIDO DE CINC (BLANCO O FLOR DE CINC)  LIMA Y CALLAO
# 3        2817001000 OXIDO DE CINC (BLANCO O FLOR DE CINC)  LIMA Y CALLAO
# 4       7901110000 CINC SIN ALEAR, CON UN CONTENIDO DE...  LIMA Y CALLAO
# ...                                                   ...            ...
# 241028  6802210000 MARMOL,TRAVERTINOS Y ALABASTRO,SIMP...  LIMA Y CALLAO
# 241029         4202991000 DEMAS SACOS DE VIAJE Y MOCHILAS  LIMA Y CALLAO
# 241030  6101300000 ABRIGOS,CHAQ.,CAPAS Y ART. SIMIL.DE...  LIMA Y CALLAO
# 241031  6110191090 DEMÁS SUÉTERES (JERSEYS), DE PUNTO,...  LIMA Y CALLAO
# 241032  6110301000 SUETERES, PULLOVERS, CARDIGANS, CHA...  LIMA Y CALLAO
#
#        Tamaño 2022 Tamaño 2023
# 0           Grande      Grande
# 1           Grande      Grande
# 2           Grande      Grande
# 3           Grande      Grande
# 4           Grande      Grande
# ...            ...         ...
# 241028      Grande      Grande
# 241029      Grande      Grande
# 241030      Grande      Grande
# 241031      Grande      Grande
# 241032      Grande      Grande
#
# [241033 rows x 19 columns]

# %%
def multiorigenes(df, anio: int=None, tipo=0):

    """
    Muestra el número de empresas exportadoras por región de origen.
    :df: DataFrame.
    :anio: Último año de análisis (opcional, por defecto último año del dataframe).
    :tipo: Tipo de exportación (0: anual acumulado, 1: mes específico).
    """
    if tipo not in (0, 1):
      print("Error: el argumento 'tipo' solo acepta los valores 0 (acumulado anual) o 1 (mensual).")
      return

    #Si no se declara argumento 'anio', se utiliza, por defecto, el año actual.
    min_AA= min(df["AA"].unique())
    max_AA= max(df["AA"].unique())
    if anio is None:
      anio = max_AA
    elif not isinstance(anio, int) or anio<min_AA or anio>max_AA:
      print(f"Error: en este caso, a partir del análisis de la base de datos, el argumento 'anio' solo acepta valores enteros, desde {min_AA} hasta {max_AA}.")
      return

    #Determina cuántos años (máx. 10) se analizarán contando a partir del último año del dataframe.
    intentos2=3
    while True:
      intentos2-=1
      if intentos2==0:
        print("Excedió el límite de intentos.")
        return
      try:
        n = int(input(f"Ingrese el número de años a analizar, contando desde el argumento 'anio' (en este caso: {anio}): "))
        if 1<=n<=(anio - min_AA + 1):
          break # Sale del bucle si n es válido
        else:
          print(f'En este caso, a partir del análisis de la base de datos, el número de años a analizar debe ser menor o igual a {anio-min_AA+1}.')
      except ValueError:
        print('Error: el número de años a analizar debe ser un número entero.')

    #Creamos diccionario vacío para almacenar "SUB" DataFrames filtrados por año.
    df_dict = {}
    if tipo==0 :
      for i in range(0,n):
        df_dict[f'df{anio-i}'] = df[df['AA'] == anio-i]
    elif tipo==1 :
      intentos3=3
      min_MM=min(df["MM"].unique())
      max_MM=max(df["MM"].unique())
      while True:
        intentos3-=1
        if intentos3==0:
          print("Excedió el límite de intetos.")
          return
        try:
          mes = int(input(f"Ingrese el mes  (a partir del análisis de la base de datos: [{min_MM}, {max_MM}]): "))
          if min_MM <= mes <= max_MM:
              break  # Salir del bucle si el mes es válido
          else:
              print(f'En este caso, a partir del análisis de la base de datos, el mes debe ser un número entero, desde {min_MM} hasta {max_MM}.')
        except ValueError:
          print('Error: el mes debe ser un número entero.')

      for i in range(0,n):
          df_dict[f'df{anio-i}'] = df[(df['AA'] == anio-i) & (df['MM']==mes)]

    #Aplicación de filtros al DataFrame.
    import pandas as pd
    #Creamos diccinario vacío para almacenar Dataframes filtrados por año y FOB.
    multiorigenes_dict = {}
    for i in range(0,n):
      #Agrupa por empresa, país y tamaño, y calcula la suma de ventas.
      f_multiorigenes = df_dict[f'df{anio-i}'].groupby(
          ['NUM_DOCUMENTO', 'DPTO', f'Tamaño {anio-i}'], as_index=False).agg({'FOB': 'sum'})
      #Calcula las ventas por empresa utilizando el DataFrame filtrado original.
      ventas_por_empresa = df_dict[f'df{anio-i}'].groupby('NUM_DOCUMENTO')['FOB'].sum().reset_index()
      ventas_por_empresa = ventas_por_empresa.rename(columns={'FOB': 'VentaTotal'})
      #Fusiona los DataFrames para combinar las ventas por empresa.
      f_multiorigenes = pd.merge(f_multiorigenes, ventas_por_empresa, on='NUM_DOCUMENTO')
      #Selecciona las columnas necesarias
      f_multiorigenes = f_multiorigenes[['NUM_DOCUMENTO', 'DPTO', f'Tamaño {anio-i}', 'FOB', 'VentaTotal']]
      f_multiorigenes.reset_index(drop=True, inplace=True)
      #Filtra los datos de empresas cuyas ventas totales sean >=1000 y, a su vez, que sus ventas por país >=1000
      #Nota: supongamos que una empresa exporta $1000: $500 Argentina y $500 Chile, entonces, esta empresa se considerará
      #en el conteo de empresas exportadoras (>=1000), PERO, NO se considerará en los origenes Argentina y Chile.
      f_multiorigenes = f_multiorigenes.loc[(f_multiorigenes['VentaTotal'] >= 1000) & (f_multiorigenes['FOB'] >= 1000)]

      #Inserta "SUB"-dataframes al diccionario.
      if tipo==0 :
        #Extrae columnas RUC, PAIS, Tamaño, y agrupa por PAIS y Tamaño. Luego, cuenta empresas existentes por PAIS y Tamaño.
        multiorigenes_dict[f'{anio-i}'] = f_multiorigenes.loc[
            :,['NUM_DOCUMENTO', 'DPTO', f'Tamaño {anio-i}']
            ].groupby(
            ['DPTO', f'Tamaño {anio-i}'],as_index=False
            )['NUM_DOCUMENTO'].count()
        #Cambio de nombre Tamaño {anio-i} a 'Tamanio'
        #Importante: este nombre debe coincidir con el DF utilizado en el Merge final
        multiorigenes_dict[f'{anio-i}'].rename(
            columns={f'Tamaño {anio-i}':'Tamanio','NUM_DOCUMENTO':f'Empresas_{anio-i}'}, inplace=True)
      else :
        #Extrae columnas RUC y PAIS, y agrupa por PAIS. Luego, cuenta empresas existentes por PAIS.
        intentos4 = 4
        while True:
          intentos4-=1
          if intentos4==0:
            print("Excedió el límite de intentos.")
            return
          try:
            rpta = str(input(f"¿Desea incluir la clasificación por tamaño? (solo escriba: SI o NO): "))
            if rpta == 'SI':
              multiorigenes_dict[f'{anio-i}'] = f_multiorigenes.loc[
                  :, ['NUM_DOCUMENTO', 'DPTO', f'Tamaño {anio-i}']
                  ].groupby(
                      ['DPTO', f'Tamaño {anio-i}'], as_index=False
                      )['NUM_DOCUMENTO'].count()
              multiorigenes_dict[f'{anio-i}'].rename(
                  columns={f'Tamaño {anio-i}':'Tamanio', 'NUM_DOCUMENTO':f'Empresas_{anio-i}_{mes}'}, inplace=True
                  )
              break  # Salir del bucle si el mes es válido
            elif rpta =='NO':
              multiorigenes_dict[f'{anio-i}'] = f_multiorigenes.loc[
                  :, ['NUM_DOCUMENTO', 'DPTO']
                  ].groupby(
                      ['DPTO'], as_index=False
                      )['NUM_DOCUMENTO'].count()
              multiorigenes_dict[f'{anio-i}'].rename(
                  columns={'NUM_DOCUMENTO':f'Empresas_{anio-i}_{mes}'}, inplace=True
                  )
              break
          except ValueError:
            print('Error: solo debe escribir "SI" o "NO"')

    #Construyendo el Merge Final.
    from itertools import product
    #Se crea la tupla 'origenes' (no modificable post creación)
    origenes= ("LIMA", "CALLAO", "PIURA", "ICA", "TACNA", "AREQUIPA",
               "LA LIBERTAD", "ANCASH", "LAMBAYEQUE", "TUMBES", "MOQUEGUA",
               "JUNIN", "PUNO", "CAJAMARCA", "CUSCO", "AYACUCHO", "HUANUCO",
               "PASCO", "APURIMAC", "HUANCAVELICA", "LORETO", "SAN MARTIN",
               "UCAYALI", "MADRE DE DIOS", "AMAZONAS"
               )
    #Se crea la tupla 'tamanos' (no modificable post creación)
    tamanos= (
        'Grande',
        'Mediana',
        'Pequeña',
        'Microempresa'
      )

    if tipo==0 :
      #Se crea el producto cartesiano entre origenes y tamanos.
      #Importante: la columna 'Tamanio' debe coincidir con el nombre del if tipo==0 del 1° for
      pxt=pd.DataFrame(product(origenes,tamanos),columns=['DPTO','Tamanio'])
      #Merge entre pxt y los "SUB" dataframes de multiorigenes_dict
      multiorigenes=pd.merge(pxt, multiorigenes_dict[f'{anio}'], how= 'outer', on=['DPTO','Tamanio'])
      for j in range (1,n):
        multiorigenes = pd.merge(
            multiorigenes,
            multiorigenes_dict[f'{anio-j}'],
            how= 'outer',
            on=['DPTO','Tamanio']
            )
    else :
      if rpta == 'SI':
        pxt=pd.DataFrame(product(origenes, tamanos),columns=['DPTO', 'Tamanio'])
        multiorigenes=pd.merge(pxt, multiorigenes_dict[f'{anio}'], how= 'outer', on=['DPTO', 'Tamanio'])
        for j in range (1,n):
          multiorigenes = pd.merge(
              multiorigenes,
              multiorigenes_dict[f'{anio-j}'],
              how= 'outer',
              on=['DPTO', 'Tamanio']
              )
      elif rpta == 'NO':
        pxt=pd.DataFrame(origenes,columns=['DPTO'])
        multiorigenes=pd.merge(pxt, multiorigenes_dict[f'{anio}'], how= 'outer', on=['DPTO'])
        for j in range (1,n):
          multiorigenes = pd.merge(
              multiorigenes,
              multiorigenes_dict[f'{anio-j}'],
              how= 'outer',
              on=['DPTO']
              )

    #Exporta a Excel.
    multiorigenes.to_excel(f'multiorigenes_tipo{tipo}.xlsx', index=False)

# %%
multiorigenes(df,2023,1)
# Out:
# Ingrese el número de años a analizar, contando desde el argumento 'anio' (en este caso: 2023): 1
# Ingrese el mes [1, 6] (a partir del análisis de la base de datos): 6
# ¿Desea incluir la clasificación por tamaño? (solo escriba: SI o NO): NO
